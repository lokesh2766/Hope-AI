# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
num1= 10
print("num1:",num1)
num2=30
print("num2:",num2 )
add=num1+num2
print("add:",add)
# Out:
# num1: 10
# num2: 30
# add: 40

# %%
#Body Mass Index

# %%
BMI=int(input("Enter the BMI Index:"))
# Out:
# Enter the BMI Index: 30

# %%
if(BMI<18):
    print("Under Wight")
elif(BMI<25):
    print("Normal Wight")
elif(BMI<30):
    print("Over Wight")
else:
    print("Very Over Wight")
# Out:
# Very Over Wight
